# %% [markdown]
# # Part One:
# ### Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f921a495ac4362feb1ecbfeb0abb1b88

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Use enumerate to get the index of the city for logging purposes and 
# the city for creating an endpoint URL

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        try: 
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try: 
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mayumba
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | meadow lake
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | nishihara
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | maltahohe
# Processing Record 15 of Set 1 | mollendo
# Processing Record 16 of Set 1 | okhotsk
# Processing Record 17 of Set 1 | paita
# Processing Record 18 of Set 1 | tombouctou
# Processing Record 19 of Set 1 | sao joao da barra
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | rio grande
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | bandarbeyla
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | vostok
# Processing Record 30 of Set 1 | araceli
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 34 of Set 1 | najran
# Processing Record 35 of Set 1 | samarai
# Processing Record 36 of Set 1 | sagae
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | hohhot
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | toba
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | caucaia
# Processing Record 45 of Set 1 | naryan-mar
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | kieta
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | kumbo
# Processing Record 50 of Set 1 | ucluelet
# Processing Record 1 of Set 2 | tabas
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | chapais
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | kurilsk
# Processing Record 8 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | tarbagatay
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | killybegs
# Processing Record 13 of Set 2 | lakes entrance
# Processing Record 14 of Set 2 | walvis bay
# Processing Record 15 of Set 2 | iskateley
# Processing Record 16 of Set 2 | kendari
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | corinto
# Processing Record 19 of Set 2 | soe
# Processing Record 20 of Set 2 | klaksvik
# Processing Record 21 of Set 2 | ayan
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | hualmay
# Processing Record 25 of Set 2 | talara
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | college
# Processing Record 28 of Set 2 | teya
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | asau
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | isangel
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | port-gentil
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | vila velha
# Processing Record 42 of Set 2 | uni
# Processing Record 43 of Set 2 | kielce
# Processing Record 44 of Set 2 | carbonia
# Processing Record 45 of Set 2 | kamyshlov
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 2 | zyryanka
# Processing Record 1 of Set 3 | mangalia
# Processing Record 2 of Set 3 | odweyne
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | faya
# Processing Record 5 of Set 3 | tra vinh
# Processing Record 6 of Set 3 | unai
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | calvinia
# Processing Record 12 of Set 3 | ubinskoye
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | oktyabrskiy
# Processing Record 15 of Set 3 | sibolga
# Processing Record 16 of Set 3 | itoman
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | nowy tomysl
# Processing Record 19 of Set 3 | tianmen
# Processing Record 20 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | lashio
# Processing Record 25 of Set 3 | shahr-e babak
# Processing Record 26 of Set 3 | tres arroyos
# Processing Record 27 of Set 3 | cedar city
# Processing Record 28 of Set 3 | vestmanna
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | nabire
# Processing Record 31 of Set 3 | tocopilla
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3 | chiredzi
# Processing Record 36 of Set 3 | melfi
# Processing Record 37 of Set 3 | ferkessedougou
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | itum-kale
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | marathon
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | sudak
# Processing Record 44 of Set 3 | belaya gora
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 3 | paramonga
# Processing Record 48 of Set 3 | rocha
# Processing Record 49 of Set 3 | butaritari
# Processing Record 50 of Set 3 | hobart
# Processing Record 1 of Set 4 | atkarsk
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | almaznyy
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | kyra
# Processing Record 12 of Set 4 | arrifes
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | bengkulu
# Processing Record 15 of Set 4 | puerto leguizamo
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | anqiu
# Processing Record 18 of Set 4 | lively
# Processing Record 19 of Set 4 | lar gerd
# City not found. Skipping...
# Processing Record 20 of Set 4 | jiazi
# Processing Record 21 of Set 4 | havre-saint-pierre
# Processing Record 22 of Set 4 | siocon
# Processing Record 23 of Set 4 | san lorenzo
# Processing Record 24 of Set 4 | paracuru
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | worland
# Processing Record 28 of Set 4 | kamien pomorski
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | sagua la grande
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | pafos
# Processing Record 33 of Set 4 | coffs harbour
# Processing Record 34 of Set 4 | pitkyaranta
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | gobo
# Processing Record 38 of Set 4 | sovetskiy
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | alexander city
# Processing Record 41 of Set 4 | atuntaqui
# Processing Record 42 of Set 4 | chicama
# Processing Record 43 of Set 4 | talcahuano
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | qaqortoq
# Processing Record 46 of Set 4 | halifax
# Processing Record 47 of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record 48 of Set 4 | hede
# Processing Record 49 of Set 4 | ewa beach
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | shieli
# Processing Record 2 of Set 5 | saint-joseph
# Processing Record 3 of Set 5 | arkadelphia
# Processing Record 4 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 5 of Set 5 | sanwer
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | preston
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | diffa
# Processing Record 10 of Set 5 | sobolevo
# Processing Record 11 of Set 5 | bubaque
# Processing Record 12 of Set 5 | port hedland
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | brae
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | whitewater
# Processing Record 17 of Set 5 | orbetello
# Processing Record 18 of Set 5 | puerto escondido
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | tumut
# Processing Record 21 of Set 5 | evensk
# Processing Record 22 of Set 5 | grajau
# Processing Record 23 of Set 5 | quatre cocos
# Processing Record 24 of Set 5 | karangampel
# Processing Record 25 of Set 5 | tezu
# Processing Record 26 of Set 5 | borlange
# City not found. Skipping...
# Processing Record 27 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 5 | kahului
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | moron
# Processing Record 31 of Set 5 | lavrentiya
# Processing Record 32 of Set 5 | antsohihy
# Processing Record 33 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 5 | alofi
# Processing Record 35 of Set 5 | alta floresta
# Processing Record 36 of Set 5 | morgantown
# Processing Record 37 of Set 5 | antofagasta
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | nicoya
# Processing Record 40 of Set 5 | castro
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | miyako
# Processing Record 43 of Set 5 | livingston
# Processing Record 44 of Set 5 | wuxi
# Processing Record 45 of Set 5 | albanel
# Processing Record 46 of Set 5 | edd
# Processing Record 47 of Set 5 | lyaskelya
# Processing Record 48 of Set 5 | toora-khem
# Processing Record 49 of Set 5 | tilichiki
# Processing Record 50 of Set 5 | wairoa
# Processing Record 1 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 6 | bilma
# Processing Record 3 of Set 6 | mwene-ditu
# Processing Record 4 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | merauke
# Processing Record 6 of Set 6 | dali
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | padang
# Processing Record 9 of Set 6 | kingman
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | aitape
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | marienburg
# Processing Record 16 of Set 6 | sioux lookout
# Processing Record 17 of Set 6 | tharrawaddy
# City not found. Skipping...
# Processing Record 18 of Set 6 | keetmanshoop
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | parichhatgarh
# Processing Record 21 of Set 6 | lata
# Processing Record 22 of Set 6 | martapura
# Processing Record 23 of Set 6 | bayir
# Processing Record 24 of Set 6 | le port
# Processing Record 25 of Set 6 | hithadhoo
# Processing Record 26 of Set 6 | korla
# Processing Record 27 of Set 6 | waling
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | salekhard
# Processing Record 30 of Set 6 | houma
# Processing Record 31 of Set 6 | joshimath
# Processing Record 32 of Set 6 | moree
# Processing Record 33 of Set 6 | goundam
# Processing Record 34 of Set 6 | saint-georges
# Processing Record 35 of Set 6 | san vicente
# Processing Record 36 of Set 6 | borogontsy
# Processing Record 37 of Set 6 | matagami
# Processing Record 38 of Set 6 | kaya
# Processing Record 39 of Set 6 | ponta delgada
# Processing Record 40 of Set 6 | athmallik
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | kaitangata
# Processing Record 43 of Set 6 | tabou
# Processing Record 44 of Set 6 | hay river
# Processing Record 45 of Set 6 | san rafael
# Processing Record 46 of Set 6 | pevek
# Processing Record 47 of Set 6 | sydney
# Processing Record 48 of Set 6 | dzaoudzi
# Processing Record 49 of Set 6 | marawi
# Processing Record 50 of Set 6 | dzilam gonzalez
# Processing Record 1 of Set 7 | pangody
# Processing Record 2 of Set 7 | vanavara
# Processing Record 3 of Set 7 | sidi ali
# Processing Record 4 of Set 7 | seoul
# Processing Record 5 of Set 7 | mount isa
# Processing Record 6 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 7 | ust-karsk
# Processing Record 8 of Set 7 | nimes
# Processing Record 9 of Set 7 | sarangani
# Processing Record 10 of Set 7 | fort nelson
# Processing Record 11 of Set 7 | bonthe
# Processing Record 12 of Set 7 | gazanjyk
# Processing Record 13 of Set 7 | narsaq
# Processing Record 14 of Set 7 | swan hill
# Processing Record 15 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 17 of Set 7 | mecca
# Processing Record 18 of Set 7 | yarmouth
# Processing Record 19 of Set 7 | decatur
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 7 | farah
# Processing Record 23 of Set 7 | nivala
# Processing Record 24 of Set 7 | vaxjo
# Processing Record 25 of Set 7 | calbuco
# Processing Record 26 of Set 7 | ust-nera
# Processing Record 27 of Set 7 | jiaojiang
# Processing Record 28 of Set 7 | puerto quijarro
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | eyl
# Processing Record 31 of Set 7 | arlit
# Processing Record 32 of Set 7 | kirakira
# Processing Record 33 of Set 7 | molchanovo
# Processing Record 34 of Set 7 | ketchikan
# Processing Record 35 of Set 7 | nara
# Processing Record 36 of Set 7 | sao filipe
# Processing Record 37 of Set 7 | garowe
# Processing Record 38 of Set 7 | xining
# Processing Record 39 of Set 7 | chalus
# Processing Record 40 of Set 7 | nouakchott
# Processing Record 41 of Set 7 | akot
# Processing Record 42 of Set 7 | nizhniy kuranakh
# Processing Record 43 of Set 7 | butembo
# Processing Record 44 of Set 7 | san francisco
# Processing Record 45 of Set 7 | thunder bay
# Processing Record 46 of Set 7 | avera
# Processing Record 47 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 7 | vardo
# Processing Record 49 of Set 7 | gasa
# Processing Record 50 of Set 7 | multai
# Processing Record 1 of Set 8 | kamaishi
# Processing Record 2 of Set 8 | pudozh
# Processing Record 3 of Set 8 | mufumbwe
# Processing Record 4 of Set 8 | asaba
# Processing Record 5 of Set 8 | saint-augustin
# Processing Record 6 of Set 8 | tamandare
# Processing Record 7 of Set 8 | trelew
# Processing Record 8 of Set 8 | sorong
# Processing Record 9 of Set 8 | turayf
# Processing Record 10 of Set 8 | bambous virieux
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | boa vista
# Processing Record 14 of Set 8 | khuzhir
# Processing Record 15 of Set 8 | luena
# Processing Record 16 of Set 8 | shu
# Processing Record 17 of Set 8 | ugoofaaru
# Processing Record 18 of Set 8 | shelburne
# Processing Record 19 of Set 8 | atambua
# Processing Record 20 of Set 8 | buraydah
# Processing Record 21 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 8 | north platte
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | yar-sale
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | manggar
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 8 | kattivakkam
# Processing Record 30 of Set 8 | kirensk
# Processing Record 31 of Set 8 | fukue
# Processing Record 32 of Set 8 | goreloye
# Processing Record 33 of Set 8 | lewisburg
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | urucara
# Processing Record 36 of Set 8 | amga
# Processing Record 37 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | biloela
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | tadine
# Processing Record 42 of Set 8 | kalmunai
# Processing Record 43 of Set 8 | saint-pierre
# Processing Record 44 of Set 8 | sao jose da coroa grande
# Processing Record 45 of Set 8 | shirokiy
# Processing Record 46 of Set 8 | dhanera
# Processing Record 47 of Set 8 | calama
# Processing Record 48 of Set 8 | atocha
# Processing Record 49 of Set 8 | port augusta
# Processing Record 50 of Set 8 | waddan
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | bemidji
# Processing Record 3 of Set 9 | meulaboh
# Processing Record 4 of Set 9 | derazhnya
# Processing Record 5 of Set 9 | la macarena
# Processing Record 6 of Set 9 | seymchan
# Processing Record 7 of Set 9 | price
# Processing Record 8 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 9 | siderno
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | middelburg
# Processing Record 12 of Set 9 | tsaratanana
# Processing Record 13 of Set 9 | izazi
# Processing Record 14 of Set 9 | pyatnitskoye
# Processing Record 15 of Set 9 | contamana
# Processing Record 16 of Set 9 | mantua
# Processing Record 17 of Set 9 | quesnel
# Processing Record 18 of Set 9 | gat
# Processing Record 19 of Set 9 | longonjo
# Processing Record 20 of Set 9 | olafsvik
# Processing Record 21 of Set 9 | flagstaff
# Processing Record 22 of Set 9 | makakilo city
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | aswan
# Processing Record 26 of Set 9 | sinnamary
# Processing Record 27 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 9 | mehamn
# Processing Record 29 of Set 9 | hamilton
# Processing Record 30 of Set 9 | kodinsk
# Processing Record 31 of Set 9 | broome
# Processing Record 32 of Set 9 | at-bashi
# Processing Record 33 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 34 of Set 9 | grand gaube
# Processing Record 35 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | rafraf
# Processing Record 38 of Set 9 | russell
# Processing Record 39 of Set 9 | petatlan
# Processing Record 40 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 41 of Set 9 | la ronge
# Processing Record 42 of Set 9 | shingu
# Processing Record 43 of Set 9 | lebedyan
# Processing Record 44 of Set 9 | tuatapere
# Processing Record 45 of Set 9 | galdar
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | ingham
# Processing Record 48 of Set 9 | dingle
# Processing Record 49 of Set 9 | sampit
# Processing Record 50 of Set 9 | mookane
# Processing Record 1 of Set 10 | solnechnyy
# Processing Record 2 of Set 10 | bongandanga
# Processing Record 3 of Set 10 | alexandroupoli
# Processing Record 4 of Set 10 | wau
# Processing Record 5 of Set 10 | luanda
# Processing Record 6 of Set 10 | cayenne
# Processing Record 7 of Set 10 | zaysan
# Processing Record 8 of Set 10 | antalaha
# Processing Record 9 of Set 10 | santa isabel do rio negro
# Processing Record 10 of Set 10 | rawson
# Processing Record 11 of Set 10 | imbituba
# Processing Record 12 of Set 10 | kuching
# Processing Record 13 of Set 10 | lincoln
# Processing Record 14 of Set 10 | praia da vitoria
# Processing Record 15 of Set 10 | sarkand
# Processing Record 16 of Set 10 | havelock
# Processing Record 17 of Set 10 | mogadishu
# Processing Record 18 of Set 10 | karratha
# Processing Record 19 of Set 10 | esso
# Processing Record 20 of Set 10 | san isidro
# Processing Record 21 of Set 10 | simpang
# Processing Record 22 of Set 10 | tukrah
# Processing Record 23 of Set 10 | ciudad bolivar
# Processing Record 24 of Set 10 | kondagaon
# Processing Record 25 of Set 10 | launceston
# Processing Record 26 of Set 10 | danjiangkou
# Processing Record 27 of Set 10 | fengxian
# Processing Record 28 of Set 10 | lhokseumawe
# Processing Record 29 of Set 10 | ayagoz
# Processing Record 30 of Set 10 | half moon bay
# Processing Record 31 of Set 10 | wuwei
# Processing Record 32 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | christchurch
# Processing Record 35 of Set 10 | mahebourg
# Processing Record 36 of Set 10 | hofn
# Processing Record 37 of Set 10 | auki
# Processing Record 38 of Set 10 | crixas
# Processing Record 39 of Set 10 | winnemucca
# Processing Record 40 of Set 10 | turukhansk
# Processing Record 41 of Set 10 | riyadh
# Processing Record 42 of Set 10 | wageningen
# Processing Record 43 of Set 10 | alugan
# Processing Record 44 of Set 10 | sharan
# Processing Record 45 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 10 | shumskiy
# Processing Record 47 of Set 10 | semey
# Processing Record 48 of Set 10 | cabo san lucas
# Processing Record 49 of Set 10 | hwange
# Processing Record 50 of Set 10 | arilje
# Processing Record 1 of Set 11 | baykit
# Processing Record 2 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 11 | kroderen
# City not found. Skipping...
# Processing Record 4 of Set 11 | uchiza
# Processing Record 5 of Set 11 | dera ghazi khan
# Processing Record 6 of Set 11 | bernalillo
# Processing Record 7 of Set 11 | meghri
# Processing Record 8 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 11 | sabang
# Processing Record 10 of Set 11 | mackay
# Processing Record 11 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 11 | mogocha
# Processing Record 13 of Set 11 | pochutla
# Processing Record 14 of Set 11 | sambava
# Processing Record 15 of Set 11 | inuvik
# Processing Record 16 of Set 11 | zaterechnyy
# Processing Record 17 of Set 11 | lyngseidet
# Processing Record 18 of Set 11 | flinders
# Processing Record 19 of Set 11 | abha
# Processing Record 20 of Set 11 | talant
# Processing Record 21 of Set 11 | takoradi
# Processing Record 22 of Set 11 | shilka
# Processing Record 23 of Set 11 | rodrigues alves
# Processing Record 24 of Set 11 | gobabis
# Processing Record 25 of Set 11 | haines junction
# Processing Record 26 of Set 11 | biak
# Processing Record 27 of Set 11 | kouango
# Processing Record 28 of Set 11 | dom pedrito
# Processing Record 29 of Set 11 | eregli
# Processing Record 30 of Set 11 | popondetta
# Processing Record 31 of Set 11 | ancud
# Processing Record 32 of Set 11 | guerrero negro
# Processing Record 33 of Set 11 | lasa
# Processing Record 34 of Set 11 | lishu
# Processing Record 35 of Set 11 | howard springs
# Processing Record 36 of Set 11 | keti bandar
# Processing Record 37 of Set 11 | araguari
# Processing Record 38 of Set 11 | wakkanai
# Processing Record 39 of Set 11 | canutama
# Processing Record 40 of Set 11 | husavik
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 43 of Set 11 | xichang
# Processing Record 44 of Set 11 | kangaba
# Processing Record 45 of Set 11 | muravlenko
# Processing Record 46 of Set 11 | pitimbu
# Processing Record 47 of Set 11 | fengrun
# Processing Record 48 of Set 11 | beitbridge
# Processing Record 49 of Set 11 | le vauclin
# Processing Record 50 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 12 | aguilar de la frontera
# Processing Record 2 of Set 12 | thinadhoo
# Processing Record 3 of Set 12 | liverpool
# Processing Record 4 of Set 12 | san andres
# Processing Record 5 of Set 12 | flin flon
# Processing Record 6 of Set 12 | derzhavinsk
# Processing Record 7 of Set 12 | svetlogorsk
# Processing Record 8 of Set 12 | verkhnevilyuysk
# Processing Record 9 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 12 | batie
# Processing Record 11 of Set 12 | kenora
# Processing Record 12 of Set 12 | mishan
# Processing Record 13 of Set 12 | kampot
# Processing Record 14 of Set 12 | ilhabela
# Processing Record 15 of Set 12 | sorland
# Processing Record 16 of Set 12 | dharchula
# Processing Record 17 of Set 12 | ngunguru
# Processing Record 18 of Set 12 | atar
# Processing Record 19 of Set 12 | cordoba
# Processing Record 20 of Set 12 | santiago del estero
# Processing Record 21 of Set 12 | dongsheng
# Processing Record 22 of Set 12 | gamba
# Processing Record 23 of Set 12 | los llanos de aridane
# Processing Record 24 of Set 12 | trairi
# Processing Record 25 of Set 12 | the valley
# Processing Record 26 of Set 12 | coahuayana
# Processing Record 27 of Set 12 | valdivia
# Processing Record 28 of Set 12 | nuevo progreso
# Processing Record 29 of Set 12 | bonavista
# Processing Record 30 of Set 12 | kyaikkami
# Processing Record 31 of Set 12 | atikokan
# Processing Record 32 of Set 12 | qidong
# Processing Record 33 of Set 12 | bambanglipuro
# Processing Record 34 of Set 12 | mozarlandia
# Processing Record 35 of Set 12 | acajutla
# Processing Record 36 of Set 12 | zalantun
# Processing Record 37 of Set 12 | buala
# Processing Record 38 of Set 12 | ohangaron
# Processing Record 39 of Set 12 | kaeo
# Processing Record 40 of Set 12 | kulhudhuffushi
# Processing Record 41 of Set 12 | arroio grande
# Processing Record 42 of Set 12 | pokrovsk
# Processing Record 43 of Set 12 | lokosovo
# Processing Record 44 of Set 12 | katherine
# Processing Record 45 of Set 12 | zhigansk
# Processing Record 46 of Set 12 | falesti
# Processing Record 47 of Set 12 | sao desiderio
# Processing Record 48 of Set 12 | qiongshan
# Processing Record 49 of Set 12 | beringovskiy
# Processing Record 50 of Set 12 | abengourou
# Processing Record 1 of Set 13 | dunedin
# Processing Record 2 of Set 13 | seydi
# Processing Record 3 of Set 13 | port shepstone
# Processing Record 4 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 13 | ojinaga
# Processing Record 6 of Set 13 | kikwit
# Processing Record 7 of Set 13 | nabul
# City not found. Skipping...
# Processing Record 8 of Set 13 | kamenka
# Processing Record 9 of Set 13 | havoysund
# Processing Record 10 of Set 13 | fort-shevchenko
# Processing Record 11 of Set 13 | eureka
# Processing Record 12 of Set 13 | iqaluit
# Processing Record 13 of Set 13 | strelka
# Processing Record 14 of Set 13 | virginia beach
# Processing Record 15 of Set 13 | yakeshi
# Processing Record 16 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 13 | ligayan
# Processing Record 18 of Set 13 | road town
# Processing Record 19 of Set 13 | rio brilhante
# Processing Record 20 of Set 13 | harper
# Processing Record 21 of Set 13 | nelson bay
# Processing Record 22 of Set 13 | vila do maio
# Processing Record 23 of Set 13 | khandyga
# Processing Record 24 of Set 13 | progreso
# Processing Record 25 of Set 13 | robertsport
# Processing Record 26 of Set 13 | savannah bight
# Processing Record 27 of Set 13 | sehwan
# Processing Record 28 of Set 13 | inzer
# Processing Record 29 of Set 13 | egvekinot
# Processing Record 30 of Set 13 | kharp
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 579

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Albany  42.60  -73.97     78.01        66          18        2.66
# 1       Mayumba  -3.43   10.66     69.35        89           0        3.22
# 2     Cape Town -33.93   18.42     55.00       100          75        8.05
# 3       Rikitea -23.12 -134.97     70.56        54          47       13.71
# 4     Jamestown  42.10  -79.24     68.00        93          90        3.36
# 5  Ponta Do Sol  32.67  -17.10     69.80        68          40        9.17
# 6      Luderitz -26.65   15.16     46.40       100           0        5.82
# 7      Hermanus -34.42   19.23     43.00        97           8        1.01
# 8   Meadow Lake  34.80 -106.54     82.40        14          20        9.17
# 9        Dikson  73.51   80.55     47.05        73          60       15.19
#
#   Country Current Description  Rain (inches)  Snow (inches)
# 0      US          few clouds           0.00            0.0
# 1      GA           clear sky           0.00            0.0
# 2      ZA       broken clouds           0.00            0.0
# 3      PF    scattered clouds           0.00            0.0
# 4      US          light rain           0.25            0.0
# 5      PT    scattered clouds           0.00            0.0
# 6      NA           clear sky           0.00            0.0
# 7      ZA           clear sky           0.00            0.0
# 8      US          few clouds           0.00            0.0
# 9      RU          light rain           0.21            0.0

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain (inches)", "Snow (inches)"]
new_city_data_df=city_data_df[new_column_order]
new_city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.60  -73.97     78.01        66          18
# 1       Mayumba      GA  -3.43   10.66     69.35        89           0
# 2     Cape Town      ZA -33.93   18.42     55.00       100          75
# 3       Rikitea      PF -23.12 -134.97     70.56        54          47
# 4     Jamestown      US  42.10  -79.24     68.00        93          90
# 5  Ponta Do Sol      PT  32.67  -17.10     69.80        68          40
# 6      Luderitz      NA -26.65   15.16     46.40       100           0
# 7      Hermanus      ZA -34.42   19.23     43.00        97           8
# 8   Meadow Lake      US  34.80 -106.54     82.40        14          20
# 9        Dikson      RU  73.51   80.55     47.05        73          60
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        2.66          few clouds           0.00            0.0
# 1        3.22           clear sky           0.00            0.0
# 2        8.05       broken clouds           0.00            0.0
# 3       13.71    scattered clouds           0.00            0.0
# 4        3.36          light rain           0.25            0.0
# 5        9.17    scattered clouds           0.00            0.0
# 6        5.82           clear sky           0.00            0.0
# 7        1.01           clear sky           0.00            0.0
# 8        9.17          few clouds           0.00            0.0
# 9       15.19          light rain           0.21            0.0

# %%
# Create the output file (CSV).
output_data_file = "/Users/markeia/OneDrive/Data Analytics Bootcamp/Python Module/World_Weather_Analysis/WeatherPy_database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
